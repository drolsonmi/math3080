# %% [markdown]
# # Lecture 8 Otaining Data from API's
# __Math 3080: Fundamentals of Data Science__
#
# Reading:
# * [McKinney, *Python for Data Science*, Chapter 6](https://wesmckinney.com/book/accessing-data#io_web_apis)
#
# Class notes are found through GitHub. As changes are made, they will automatically be uploaded to GitHub. A link to the repository is on Canvas.
#
# -----
# ## Outline

# %% [markdown]
# Some live data can be obtained through web scraping. However, the best archives of data are stored in databases and can be retreived through an __Application Programming Interface (API)__. APIs are commonly used in application software, such as smartphone apps.
#
# To get data from an API in Python, we need the `requests` package.

# %%
import pandas as pd
import requests

# %% [markdown]
# In order to access an API, we generally need an *authorization key*. These are often available on webpages under the "Developers" link at the bottom of the page.
# * Example: [Yelp business search](https://www.yelp.com)
#   * Select "Developers" link on the bottom of the page
#   * If needed, enroll in an account
#   * Select "Manage API Access"
#   * Create an app
#   * After the app is created, you will see an API key at the top of the page
#
# Every API needs documentation, which generally includes examples of how to use the system. For Yelp, find the documentation here:
# * [Getting Started with the Yelp Fusion API](https://docs.developer.yelp.com/docs/fusion-intro)

# %%
api_url = "https://api.yelp.com/v3/businesses/search"

authorization = {
  'Authorization': 'Bearer hZU3WOBIK3jklJqIzew0uDFK_vjSYmoKToQQejrQuceKPGu8SF6M_-SuAT7asN6RNldA_kZvQGrE-3vh-RuQxHxRNUUKkHeRk03p_RLCQcO6ZZvHKMHoR5sEh7f3Y3Yx'
}

search_parameters = {
    'term': 'restaurants',
    'location': 'Ephraim, UT',
    'radius' : 15000,
    'limit' : 50
}

# %%
response = requests.get(api_url, headers=authorization, params=search_parameters)

# Generally a good idea to check for HTTP errors
response.raise_for_status()

# What did we get?
response.text
# Out:
# '{"businesses": [{"id": "vOsSWOhz25b7OcHtClmg7w", "alias": "roots-89-roadhouse-ephraim", "name": "Roots 89 Roadhouse", "image_url": "https://s3-media0.fl.yelpcdn.com/bphoto/2Qm6nUg4ThhhrjIjkr_zqw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/roots-89-roadhouse-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg", "review_count": 22, "categories": [{"alias": "coffee", "title": "Coffee & Tea"}, {"alias": "burgers", "title": "Burgers"}, {"alias": "bbq", "title": "Barbeque"}], "rating": 4.3, "coordinates": {"latitude": 39.3662481507577, "longitude": -111.58679385326128}, "transactions": [], "location": {"address1": "350 N Main St", "address2": "", "address3": null, "city": "Ephraim", "zip_code": "84627", "country": "US", "state": "UT", "display_address": ["350 N Main St", "Ephraim, UT 84627"]}, "phone": "+14352838889", "display_phone": "(435) 283-8889", "distance": 1038.7391872988767}, {"id": "MdpvieSSi2Z4pREUlYnl7w", "alias": "solid-rock-cafe-ephraim", "name": "Solid Rock Cafe", "image_url": "https://s3-media0.fl.yelpcdn.com/bphoto/t18VpatgR6oKNORma1BRCg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/solid-rock-cafe-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg", "review_count": 31, "categories": [{"alias": "cafes", "title": "Cafes"}, {"alias": "coffee", "title": "Coffee & Tea"}, {"alias": "bagels", "title": "Bagels"}], "rating": 4.7, "coordinates": {"latitude": 39.3597646, "longitude": -111.5842886}, "transactions": [], "price": "$", "location": {"address1": "96 E Center St", "address2": "", "address3": "", "city": "Ephraim", "zip_code": "84627", "country": "US", "state": "UT", "display_address": ["96 E Center St", "Ephraim, UT 84627"]}, "phone": "+14352830178", "display_phone": "(435) 283-0178", "distance": 360.85332426673284}, {"id": "BWh2P8LRPMP9ER2SFrnA2w", "alias": "harvest-grill-ephraim", "name": "Harvest Grill", "image_url": "", "is_closed": false, "url": "https://www.yelp.com/biz/harvest-grill-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg", "review_count": 3, "categories": [{"alias": "salad", "title": "Salad"}, {"alias": "burgers", "title": "Burgers"}, {"alias": "sandwiches", "title": "Sandwiches"}], "rating": 4.0, "coordinates": {"latitude": 39.36027, "longitude": -111.587452}, "transactions": [], "location": {"address1": "27 N Main St", "address2": null, "address3": null, "city": "Ephraim", "zip_code": "84627", "country": "US", "state": "UT", "display_address": ["27 N Main St", "Ephraim, UT 84627"]}, "phone": "+14352834755", "display_phone": "(435) 283-4755", "distance": 635.8989236977848}, {"id": "OfPUpvh77irKr2pfEYVEWg", "alias": "joses-cafe-mexican-food-ephraim", "name": "Jose\'s Cafe Mexican Food", "image_url": "https://s3-media0.fl.yelpcdn.com/bphoto/DgndQBL7JPiGptffwlWlaQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/joses-cafe-mexican-food-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg", "review_count": 78, "categories": [{"alias": "mexican", "title": "Mexican"}], "rating": 4.1, "coordinates": {"latitude": 39.36544, "longitude": -111.587203}, "transactions": [], "price": "$", "location": {"address1": "295 N Main St", "address2": "", "address3": "", "city": "Ephraim", "zip_code": "84627", "country": "US", "state": "UT", "display_address": ["295 N Main St", "Ephraim, UT 84627"]}, "phone": "+14352834425", "display_phone": "(435) 283-4425", "distance": 982.6702130815589}, {"id": "qIwElGbCtu5-Cv-20GQDAA", "alias": "roys-pizza-and-pasta-ephraim", "name": "Roy\'s Pizza & Pasta", "image_url": "https://s3-media0.fl.yelpcdn.com/bphoto/CD90xe9kBSoFOUl-aYddOA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz ...

# %% [markdown]
# The results are in *json* format. So, we need to extract the data.

# %%
data = response.json()
data
# Out:
# {'businesses': [{'id': 'vOsSWOhz25b7OcHtClmg7w',
#    'alias': 'roots-89-roadhouse-ephraim',
#    'name': 'Roots 89 Roadhouse',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/2Qm6nUg4ThhhrjIjkr_zqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roots-89-roadhouse-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 22,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 39.3662481507577,
#     'longitude': -111.58679385326128},
#    'transactions': [],
#    'location': {'address1': '350 N Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['350 N Main St', 'Ephraim, UT 84627']},
#    'phone': '+14352838889',
#    'display_phone': '(435) 283-8889',
#    'distance': 1038.7391872988767},
#   {'id': 'MdpvieSSi2Z4pREUlYnl7w',
#    'alias': 'solid-rock-cafe-ephraim',
#    'name': 'Solid Rock Cafe',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/t18VpatgR6oKNORma1BRCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/solid-rock-cafe-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 31,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 39.3597646, 'longitude': -111.5842886},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '96 E Center St',
#     'address2': '',
#     'address3': '',
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['96 E Center St', 'Ephraim, UT 84627']},
#    'phone': '+14352830178',
#    'display_phone': '(435) 283-0178',
#    'distance': 360.85332426673284},
#   {'id': 'BWh2P8LRPMP9ER2SFrnA2w',
#    'alias': 'harvest-grill-ephraim',
#    'name': 'Harvest Grill',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/harvest-grill-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 3,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.36027, 'longitude': -111.587452},
#    'transactions': [],
#    'location': {'address1': '27 N Main St',
#     'address2': None,
#     'address3': None,
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['27 N Main St', 'Ephraim, UT 84627']},
#    'phone': '+14352834755',
#    'display_phone': '(435) 283-4755',
#    'distance': 635.8989236977848},
#   {'id': 'OfPUpvh77irKr2pfEYVEWg',
#    'alias': 'joses-cafe-mexican-food-ephraim',
#    'name': "Jose's Cafe Mexican Food",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/DgndQBL7JPiGptffwlWlaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joses-cafe-mexican-food-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 78,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 39.36544, 'longitude': -111.587203},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '295 N Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['295 N Main St', 'Ephraim, UT 84627']},
#    'phone': '+14352834425',
#    'display_phone': '(435) 283-4425',
#    'distance': 982.6702130815589},
#   {'id': 'qIwElGbCtu5-Cv-20GQDAA',
#    'alias': 'roys-pizza-and-pasta-ephraim',
#    'name': "Roy's Pizza & Pasta",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/CD90xe9kBSoFOUl-aYddOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roys-pizza-and-pasta-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 70,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 39.35841, 'longitude': -111.5869},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '81 S Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['81 S Main St', 'Ephraim, UT 84627']},
#    'phone': '+14352834222',
#    'display_phone': '(435) 283-4222',
#    'distance': 529.6633893950961},
#   {'id': 'jBgH6DkVZXkSoRMBp6negw',
#    'alias': 'los-amigos-mexican-restaurant-ephraim',
#    'name': 'Los Amigos Mexican Restaurant',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/VUFTEOTaIPM5kzsUO-ONfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-amigos-mexican-restaurant-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 26,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.3,
#    'coordinates': {'latitude': 39.347626, 'longitude': -111.58785},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3 E 700th S',
#     'address2': '',
#     'address3': '',
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['3 E 700th S', 'Ephraim, UT 84627']},
#    'phone': '+14352835675',
#    'display_phone': '(435) 283-5675',
#    'distance': 1334.4775286486745},
#   {'id': 'ym5sC1Ml1CjeJchSJeNJ3g',
#    'alias': 'charlee-s-comfort-kitchen-manti',
#    'name': 'Charlee’s Comfort Kitchen',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/s9prCL1TWaAfF6PLnAff1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charlee-s-comfort-kitchen-manti?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 15,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 39.267131, 'longitude': -111.637478},
#    'transactions': [],
#    'location': {'address1': '115 N Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'Manti',
#     'zip_code': '84642',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['115 N Main St', 'Manti, UT 84642']},
#    'phone': '+14358356500',
#    'display_phone': '(435) 835-6500',
#    'distance': 11250.81339271125},
#   {'id': 'xmT_KLJ2Fh9o7ozWF-s4lQ',
#    'alias': 'the-malt-shop-ephraim-2',
#    'name': 'The Malt Shop',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/eZ25SdNFN8peEk_Fcbm0YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-malt-shop-ephraim-2?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 46,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.36257, 'longitude': -111.5869},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '150 N Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['150 N Main St', 'Ephraim, UT 84627']},
#    'phone': '+14352834101',
#    'display_phone': '(435) 283-4101',
#    'distance': 725.568952010893},
#   {'id': 'n4TJPz54pJn-BAHWTxBnHA',
#    'alias': 'millers-drive-thru-manti-2',
#    'name': "Miller's Drive-Thru",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/qgrKOtAxEpPKWe3E5WIWRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/millers-drive-thru-manti-2?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 49,
#    'categories': [{'alias': 'tradamerican', 'title': 'American'},
#     {'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 3.6,
#    'coordinates': {'latitude': 39.26871, 'longitude': -111.63713},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '227 N Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Manti',
#     'zip_code': '84642',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['227 N Main St', 'Manti, UT 84642']},
#    'phone': '+14358354931',
#    'display_phone': '(435) 835-4931',
#    'distance': 11081.270864016964},
#   {'id': 'AhJ6yH_JjlFQ50SGqi0ngA',
#    'alias': 'snocap-lanes-ephraim',
#    'name': 'SnoCap Lanes',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/vSscQ7yO1C6S0ypTlx1OJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snocap-lanes-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 21,
#    'categories': [{'alias': 'bowling', 'title': 'Bowling'},
#     {'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'arcades', 'title': 'Arcades'}],
#    'rating': 3.1,
#    'coordinates': {'latitude': 39.350511751585046,
#     'longitude': -111.58736305493916},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '605 S Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['605 S Main St', 'Ephraim, UT 84627']},
#    'phone': '+14352834522',
#    'display_phone': '(435) 283-4522',
#    'distance': 1037.474465296741},
#   {'id': 'UOInSUbHc0Lg6IblQSiSZw',
#    'alias': 'snow-dragon-chinese-ephraim',
#    'name': 'Snow Dragon Chinese',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/6Ox9VxCVnsiugGNraSBQ7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snow-dragon-chinese-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 57,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.3524651, 'longitude': -111.5870231},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '413 S Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['413 S Main St', 'Ephraim, UT 84627']},
#    'phone': '+14352836868',
#    'display_phone': '(435) 283-6868',
#    'distance': 847.945399627487},
#   {'id': 'Sq0UiTduflOyhnRMrcglFA',
#    'alias': 'zas-and-das-ephraim',
#    'name': "Za's & Da's",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/92JhxAXx2amR0lcfy845qA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zas-and-das-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 1,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.37310004505351,
#     'longitude': -111.58563997596502},
#    'transactions': [],
#    'location': {'address1': '726 N 50th E',
#     'address2': '',
#     'address3': None,
#     'city': 'Ephraim',
#     'zip_code': '84627-1124',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['726 N 50th E', 'Ephraim, UT 84627-1124']},
#    'phone': '+14352831111',
#    'display_phone': '(435) 283-1111',
#    'distance': 1709.2584749915497},
#   {'id': 'JHwcYa7UEj2WjXQxJBVDzw',
#    'alias': 'mcdonalds-ephraim',
#    'name': "McDonald's",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/3lr13KKFNzj97VJIG6OP4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mcdonalds-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 43,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 39.3500344563994,
#     'longitude': -111.587593451841},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '549 S Main',
#     'address2': '',
#     'address3': '',
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['549 S Main', 'Ephraim, UT 84627']},
#    'phone': '+14352834915',
#    'display_phone': '(435) 283-4915',
#    'distance': 1092.5983079890796},
#   {'id': 'sXfGLUEbdUL8tW8dcYfbgg',
#    'alias': 'sip-it-soda-shack-ephraim',
#    'name': 'Sip It ! Soda Shack',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/v6VvpagTIYlbsK-lB_zZNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sip-it-soda-shack-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 6,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 39.3517764076663,
#     'longitude': -111.586870706244},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '455 S Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['455 S Main St', 'Ephraim, UT 84627']},
#    'phone': '+14352833435',
#    'display_phone': '(435) 283-3435',
#    'distance': 898.4106931548133},
#   {'id': 'N__qYjfU9Jmr48_sRHa-BA',
#    'alias': 'maverik-adventures-first-stop-ephraim',
#    'name': "Maverik Adventure's First Stop",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/wHV65Y26hDg_0E6uJ0kbsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maverik-adventures-first-stop-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 10,
#    'categories': [{'alias': 'convenience', 'title': 'Convenience Stores'},
#     {'alias': 'servicestations', 'title': 'Gas Stations'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 39.36111561628707,
#     'longitude': -111.587505787611},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '89 N Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['89 N Main St', 'Ephraim, UT 84627']},
#    'phone': '+14356575507',
#    'display_phone': '(435) 657-5507',
#    'distance': 675.6041729233804},
#   {'id': '_pew3l1qqT1hem8WRzS_XA',
#    'alias': 'main-street-pizza-manti',
#    'name': 'Main Street Pizza',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/ekXTjqQvSYggUdvdTAY7GA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/main-street-pizza-manti?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 25,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 39.2638064, 'longitude': -111.6368851},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '101 S Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Manti',
#     'zip_code': '84642',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['101 S Main St', 'Manti, UT 84642']},
#    'phone': '+14358358008',
#    'display_phone': '(435) 835-8008',
#    'distance': 11554.337996779925},
#   {'id': '11qmt530qHt8zdpFIIh05Q',
#    'alias': 'subway-ephraim-2',
#    'name': 'Subway',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/DyCBJl1xMvnOMffkGjNekg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/subway-ephraim-2?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 14,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 2.7,
#    'coordinates': {'latitude': 39.3648843688261,
#     'longitude': -111.586745210708},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '290 N Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['290 N Main St', 'Ephraim, UT 84627']},
#    'phone': '+14352835015',
#    'display_phone': '(435) 283-5015',
#    'distance': 909.5162930829124},
#   {'id': 'O5gnlAKccLt7rfAW6-KDxw',
#    'alias': 'arbys-ephraim',
#    'name': "Arby's",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arbys-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 1,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'wraps', 'title': 'Wraps'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 39.37366766725062,
#     'longitude': -111.58643946966902},
#    'transactions': [],
#    'location': {'address1': '791 N 50 E',
#     'address2': '',
#     'address3': None,
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['791 N 50 E', 'Ephraim, UT 84627']},
#    'phone': '+14352834002',
#    'display_phone': '(435) 283-4002',
#    'distance': 1788.4765509232132},
#   {'id': 'V_iq0GXQOFG-ubl8cDbppw',
#    'alias': 'little-caesars-pizza-ephraim',
#    'name': 'Little Caesars Pizza',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/1LqaOtRvaaXxOBwva4okWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-caesars-pizza-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 12,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.3689502512076,
#     'longitude': -111.586572489712},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '462 N Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['462 N Main St', 'Ephraim, UT 84627']},
#    'phone': '+14352834353',
#    'display_phone': '(435) 283-4353',
#    'distance': 1298.0324024247122},
#   {'id': '3wjuq8DXZRwT4EuEouareA',
#    'alias': 'papa-murphys-ephraim',
#    'name': "Papa Murphy's",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/papa-murphys-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 6,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.373006875518534,
#     'longitude': -111.58545438576591},
#    'transactions': [],
#    'location': {'address1': '726 N 50 E',
#     'address2': None,
#     'address3': None,
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['726 N 50 E', 'Ephraim, UT 84627']},
#    'phone': '+14352831111',
#    'display_phone': '(435) 283-1111',
#    'distance': 1695.2333742762166},
#   {'id': 'yE7jaFhUcWJi0dTaYZCtMg',
#    'alias': 'wendys-ephraim',
#    'name': "Wendy's",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/izLqe7XN4zPQzmxxL89OgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wendys-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 4,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.37366502308796, 'longitude': -111.587912},
#    'transactions': [],
#    'location': {'address1': '747 N Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['747 N Main St', 'Ephraim, UT 84627']},
#    'phone': '+14352834300',
#    'display_phone': '(435) 283-4300',
#    'distance': 1827.8422678599625},
#   {'id': 'dmEkeU2liiwn-fVX6HtBtg',
#    'alias': 'pueblo-chico-market-ephraim',
#    'name': 'Pueblo Chico Market',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pueblo-chico-market-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 0,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'markets', 'title': 'Fruits & Veggies'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 0.0,
#    'coordinates': {'latitude': 39.3599576983031, 'longitude': -111.5873452},
#    'transactions': [],
#    'location': {'address1': '1 N Main St',
#     'address2': None,
#     'address3': None,
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['1 N Main St', 'Ephraim, UT 84627']},
#    'phone': '+16266467731',
#    'display_phone': '(626) 646-7731',
#    'distance': 611.7552984735655},
#   {'id': '3VNCxWFjuvmUCvHNALWq1A',
#    'alias': 'dominos-pizza-ephraim',
#    'name': "Domino's Pizza",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominos-pizza-ephraim?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 0,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 0.0,
#    'coordinates': {'latitude': 39.36827990632794, 'longitude': -111.586699},
#    'transactions': [],
#    'location': {'address1': '28 E 450 N Main St',
#     'address2': None,
#     'address3': None,
#     'city': 'Ephraim',
#     'zip_code': '84627',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['28 E 450 N Main St', 'Ephraim, UT 84627']},
#    'phone': '+18882334003',
#    'display_phone': '(888) 233-4003',
#    'distance': 1234.5418308068747},
#   {'id': 'FPakDWIvz3olHAbHcZlrzA',
#    'alias': 'charlees-comfort-kitchen-manti',
#    'name': "Charlee's Comfort Kitchen",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/Pu7iVxxPT_zHg388lvASgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charlees-comfort-kitchen-manti?adjust_creative=rAfNf1xUCz-EbUgzFpdQJg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rAfNf1xUCz-EbUgzFpdQJg',
#    'review_count': 0,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 0.0,
#    'coordinates': {'latitude': 39.26713235885457,
#     'longitude': -111.63744028279102},
#    'transactions': [],
#    'location': {'address1': '115 N Main St',
#     'address2': None,
#     'address3': None,
#     'city': 'Manti',
#     'zip_code': '84642',
#     'country': 'US',
#     'state': 'UT',
#     'display_address': ['115 N Main St', 'Manti, UT 84642']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 11248.858100637824}],
#  'total': 24,
#  'region': {'center': {'longitude': -111.58058166503906,
#    'latitude': 39.35818120287217}}}

# %%
list(data)
# Out:
# ['businesses', 'total', 'region']

# %%
restaurants = pd.DataFrame(data['businesses'])
restaurants.head(3)
# Out:
#                        id                       alias                name  \
# 0  vOsSWOhz25b7OcHtClmg7w  roots-89-roadhouse-ephraim  Roots 89 Roadhouse
# 1  MdpvieSSi2Z4pREUlYnl7w     solid-rock-cafe-ephraim     Solid Rock Cafe
# 2  BWh2P8LRPMP9ER2SFrnA2w       harvest-grill-ephraim       Harvest Grill
#
#                                            image_url  is_closed  \
# 0  https://s3-media0.fl.yelpcdn.com/bphoto/2Qm6nU...      False
# 1  https://s3-media0.fl.yelpcdn.com/bphoto/t18Vpa...      False
# 2                                                         False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/roots-89-roadhouse-ep...            22
# 1  https://www.yelp.com/biz/solid-rock-cafe-ephra...            31
# 2  https://www.yelp.com/biz/harvest-grill-ephraim...             3
#
#                                           categories  rating  \
# 0  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.3
# 1  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.7
# 2  [{'alias': 'salad', 'title': 'Salad'}, {'alias...     4.0
#
#                                          coordinates transactions  \
# 0  {'latitude': 39.3662481507577, 'longitude': -1...           []
# 1  {'latitude': 39.3597646, 'longitude': -111.584...           []
# 2   {'latitude': 39.36027, 'longitude': -111.587452}           []
#
#                                             location         phone  \
# 0  {'address1': '350 N Main St', 'address2': '', ...  +14352838889
# 1  {'address1': '96 E Center St', 'address2': '',...  +14352830178
# 2  {'address1': '27 N Main St', 'address2': None,...  +14352834755
#
#     display_phone     distance price
# 0  (435) 283-8889  1038.739187   NaN
# 1  (435) 283-0178   360.853324     $
# 2  (435) 283-4755   635.898924   NaN

# %% [markdown]
# Great! We have been able to search for and create a simple DataFrame with all of these restaurants. But now, how do we search for specific categories of food? Let's look at the "categories" column.

# %%
restaurants['categories']
# Out:
# 0     [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 1     [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...
# 2     [{'alias': 'salad', 'title': 'Salad'}, {'alias...
# 3            [{'alias': 'mexican', 'title': 'Mexican'}]
# 4     [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 5            [{'alias': 'mexican', 'title': 'Mexican'}]
# 6     [{'alias': 'comfortfood', 'title': 'Comfort Fo...
# 7     [{'alias': 'icecream', 'title': 'Ice Cream & F...
# 8     [{'alias': 'tradamerican', 'title': 'American'...
# 9     [{'alias': 'bowling', 'title': 'Bowling'}, {'a...
# 10           [{'alias': 'chinese', 'title': 'Chinese'}]
# 11               [{'alias': 'pizza', 'title': 'Pizza'}]
# 12    [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...
# 13    [{'alias': 'foodstands', 'title': 'Food Stands'}]
# 14    [{'alias': 'convenience', 'title': 'Convenienc...
# 15               [{'alias': 'pizza', 'title': 'Pizza'}]
# 16    [{'alias': 'sandwiches', 'title': 'Sandwiches'...
# 17    [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...
# 18    [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 19               [{'alias': 'pizza', 'title': 'Pizza'}]
# 20    [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...
# 21    [{'alias': 'grocery', 'title': 'Grocery'}, {'a...
# 22    [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 23         [{'alias': 'hotdogs', 'title': 'Fast Food'}]
# Name: categories, dtype: object

# %% [markdown]
# This column is an array of *json* formatted information. So, we need to extract that information. We'll do this with `pd.json_normalize()`. The result will come out with a "flattened" DataFrame.
# * By "flattened" we mean that every occurence of a category gets its own line, even if the place in question (the restaurants in this case) appears multiple times in our list

# %%
restaurants_flat = pd.json_normalize(data['businesses'],
                                     sep='_',
                                     record_path='categories',
                                     meta=['name','rating'],
                                     meta_prefix='biz_')
restaurants_flat
# Out:
#                alias                      title  \
# 0             coffee               Coffee & Tea
# 1            burgers                    Burgers
# 2                bbq                   Barbeque
# 3              cafes                      Cafes
# 4             coffee               Coffee & Tea
# 5             bagels                     Bagels
# 6              salad                      Salad
# 7            burgers                    Burgers
# 8         sandwiches                 Sandwiches
# 9            mexican                    Mexican
# 10           italian                    Italian
# 11             pizza                      Pizza
# 12        sandwiches                 Sandwiches
# 13           mexican                    Mexican
# 14       comfortfood               Comfort Food
# 15             salad                      Salad
# 16  breakfast_brunch         Breakfast & Brunch
# 17          icecream  Ice Cream & Frozen Yogurt
# 18           burgers                    Burgers
# 19      tradamerican                   American
# 20            donuts                     Donuts
# 21          icecream  Ice Cream & Frozen Yogurt
# 22           bowling                    Bowling
# 23            diners                     Diners
# 24           arcades                    Arcades
# 25           chinese                    Chinese
# 26             pizza                      Pizza
# 27           hotdogs                  Fast Food
# 28           burgers                    Burgers
# 29            coffee               Coffee & Tea
# 30        foodstands                Food Stands
# 31       convenience         Convenience Stores
# 32   servicestations               Gas Stations
# 33           hotdogs                  Fast Food
# 34             pizza                      Pizza
# 35        sandwiches                 Sandwiches
# 36           hotdogs                  Fast Food
# 37           hotdogs                  Fast Food
# 38           burgers                    Burgers
# 39             wraps                      Wraps
# 40             pizza                      Pizza
# 41     chicken_wings              Chicken Wings
# 42             pizza                      Pizza
# 43           hotdogs                  Fast Food
# 44           burgers                    Burgers
# 45           grocery                    Grocery
# 46           markets           Fruits & Veggies
# 47           mexican                    Mexican
# 48             pizza                      Pizza
# 49     chicken_wings              Chicken Wings
# 50        sandwiches                 Sandwiches
# 51           hotdogs                  Fast Food
#
#                           biz_name biz_rating
# 0               Roots 89 Roadhouse        4.3
# 1               Roots 89 Roadhouse        4.3
# 2               Roots 89 Roadhouse        4.3
# 3                  Solid Rock Cafe        4.7
# 4                  Solid Rock Cafe        4.7
# 5                  Solid Rock Cafe        4.7
# 6                    Harvest Grill        4.0
# 7                    Harvest Grill        4.0
# 8                    Harvest Grill        4.0
# 9         Jose's Cafe Mexican Food        4.1
# 10             Roy's Pizza & Pasta        4.3
# 11             Roy's Pizza & Pasta        4.3
# 12             Roy's Pizza & Pasta        4.3
# 13   Los Amigos Mexican Restaurant        3.3
# 14       Charlee’s Comfort Kitchen        4.7
# 15       Charlee’s Comfort Kitchen        4.7
# 16       Charlee’s Comfort Kitchen        4.7
# 17                   The Malt Shop        3.5
# 18                   The Malt Shop        3.5
# 19             Miller's Drive-Thru        3.6
# 20             Miller's Drive-Thru        3.6
# 21             Miller's Drive-Thru        3.6
# 22                    SnoCap Lanes        3.1
# 23                    SnoCap Lanes        3.1
# 24                    SnoCap Lanes        3.1
# 25             Snow Dragon Chinese        3.5
# 26                     Za's & Da's        5.0
# 27                      McDonald's        2.0
# 28                      McDonald's        2.0
# 29                      McDonald's        2.0
# 30             Sip It ! Soda Shack        4.3
# 31  Maverik Adventure's First Stop        4.1
# 32  Maverik Adventure's First Stop        4.1
# 33  Maverik Adventure's First Stop        4.1
# 34               Main Street Pizza        4.1
# 35                          Subway        2.7
# 36                          Subway        2.7
# 37                          Arby's        1.0
# 38                          Arby's        1.0
# 39                          Arby's        1.0
# 40            Little Caesars Pizza        3.0
# 41            Little Caesars Pizza        3.0
# 42                   Papa Murphy's        3.0
# 43                         Wendy's        2.5
# 44                         Wendy's        2.5
# 45             Pueblo Chico Market        0.0
# 46             Pueblo Chico Market        0.0
# 47             Pueblo Chico Market        0.0
# 48                  Domino's Pizza        0.0
# 49                  Domino's Pizza        0.0
# 50                  Domino's Pizza        0.0
# 51       Charlee's Comfort Kitchen        0.0

# %% [markdown]
# Now, we can narrow our search by categories.

# %%
restaurants_flat[ restaurants_flat['alias'] == "pizza" ]
# Out:
#     alias  title              biz_name biz_rating
# 11  pizza  Pizza   Roy's Pizza & Pasta        4.3
# 26  pizza  Pizza           Za's & Da's        5.0
# 34  pizza  Pizza     Main Street Pizza        4.1
# 40  pizza  Pizza  Little Caesars Pizza        3.0
# 42  pizza  Pizza         Papa Murphy's        3.0
# 48  pizza  Pizza        Domino's Pizza        0.0

# %%
restaurants_flat[ restaurants_flat['alias'] == "hotdogs" ].sort_values(by='biz_rating', ascending=False)
# Out:
#       alias      title                        biz_name biz_rating
# 33  hotdogs  Fast Food  Maverik Adventure's First Stop        4.1
# 36  hotdogs  Fast Food                          Subway        2.7
# 43  hotdogs  Fast Food                         Wendy's        2.5
# 27  hotdogs  Fast Food                      McDonald's        2.0
# 37  hotdogs  Fast Food                          Arby's        1.0
# 51  hotdogs  Fast Food       Charlee's Comfort Kitchen        0.0

# %%
restaurants_flat[ restaurants_flat['title'] == "Mexican" ]
# Out:
#       alias    title                       biz_name biz_rating
# 9   mexican  Mexican       Jose's Cafe Mexican Food        4.1
# 13  mexican  Mexican  Los Amigos Mexican Restaurant        3.3
# 47  mexican  Mexican            Pueblo Chico Market        0.0

# %% [markdown]
# -----

# %% [markdown]
# ## Practice

# %% [markdown]
# Now try it yourselves with stock data:
# * url = "
